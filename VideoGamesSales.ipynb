# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dados = pd.read_csv('vgsales.csv')
dados
# Out:
#         Rank                                              Name Platform  \
# 0          1                                        Wii Sports      Wii
# 1          2                                 Super Mario Bros.      NES
# 2          3                                    Mario Kart Wii      Wii
# 3          4                                 Wii Sports Resort      Wii
# 4          5                          Pokemon Red/Pokemon Blue       GB
# ...      ...                                               ...      ...
# 16593  16596                Woody Woodpecker in Crazy Castle 5      GBA
# 16594  16597                     Men in Black II: Alien Escape       GC
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2
# 16596  16599                                        Know How 2       DS
# 16597  16600                                  Spirits & Spells      GBA
#
#          Year         Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %%
dados = dados.rename(columns = {"Rank":"Classificacao", "Name" : "Nome", "Platform" : "Plataforma", "Year":"Ano", "Genre":"Genero","Publisher":"Editora", "NA_Sales":"Na_vendas", "EU_sales":"Eu_vendas", "JP_Sales":"Jp_vendas", "Other_Sales":"Outras_vendas", "Global_Sales":"Vendas_globais"})
dados
# Out:
#        Classificacao                                              Nome  \
# 0                  1                                        Wii Sports
# 1                  2                                 Super Mario Bros.
# 2                  3                                    Mario Kart Wii
# 3                  4                                 Wii Sports Resort
# 4                  5                          Pokemon Red/Pokemon Blue
# ...              ...                                               ...
# 16593          16596                Woody Woodpecker in Crazy Castle 5
# 16594          16597                     Men in Black II: Alien Escape
# 16595          16598  SCORE International Baja 1000: The Official Game
# 16596          16599                                        Know How 2
# 16597          16600                                  Spirits & Spells
#
#       Plataforma     Ano        Genero     Editora  Na_vendas  EU_Sales  \
# ...

# %%
dados.dropna()
# Out:
#        Classificacao                                              Nome  \
# 0                  1                                        Wii Sports
# 1                  2                                 Super Mario Bros.
# 2                  3                                    Mario Kart Wii
# 3                  4                                 Wii Sports Resort
# 4                  5                          Pokemon Red/Pokemon Blue
# ...              ...                                               ...
# 16593          16596                Woody Woodpecker in Crazy Castle 5
# 16594          16597                     Men in Black II: Alien Escape
# 16595          16598  SCORE International Baja 1000: The Official Game
# 16596          16599                                        Know How 2
# 16597          16600                                  Spirits & Spells
#
#       Plataforma     Ano        Genero     Editora  Na_vendas  EU_Sales  \
# ...

# %%
dados.dtypes
# Out:
# Classificacao       int64
# Nome               object
# Plataforma         object
# Ano               float64
# Genero             object
# Editora            object
# Na_vendas         float64
# EU_Sales          float64
# Jp_vendas         float64
# Outras_vendas     float64
# Vendas_globais    float64
# dtype: object

# %%
dados.drop(dados[dados.Vendas_globais < 0.20].index, inplace = True)
dados.drop(dados[dados.Jp_vendas < 0.05].index, inplace = True)
dados.drop(dados[dados.Outras_vendas < 0.02].index, inplace = True)

# %%
dados.describe()
# Out:
#        Classificacao          Ano    Na_vendas     EU_Sales    Jp_vendas  \
# count    1509.000000  1501.000000  1509.000000  1509.000000  1509.000000
# mean     2301.219351  2004.980680     1.075070     0.685805     0.492710
# std      2010.490001     7.066845     2.293909     1.408405     0.802441
# min         1.000000  1983.000000     0.000000     0.000000     0.050000
# 25%       553.000000  2000.000000     0.150000     0.070000     0.110000
# 50%      1697.000000  2006.000000     0.410000     0.230000     0.230000
# 75%      3707.000000  2011.000000     1.110000     0.710000     0.510000
# max      7733.000000  2016.000000    41.490000    29.020000    10.220000
#
#        Outras_vendas  Vendas_globais
# count    1509.000000     1509.000000
# mean        0.224844        2.478171
# std         0.541533        4.350769
# min         0.020000        0.200000
# 25%         0.030000        0.540000
# 50%         0.070000        1.190000
# 75%         0.210000        2.700000
# ...

# %%
dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1509 entries, 0 to 7731
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Classificacao   1509 non-null   int64
#  1   Nome            1509 non-null   object
#  2   Plataforma      1509 non-null   object
#  3   Ano             1501 non-null   float64
#  4   Genero          1509 non-null   object
#  5   Editora         1509 non-null   object
#  6   Na_vendas       1509 non-null   float64
#  7   EU_Sales        1509 non-null   float64
#  8   Jp_vendas       1509 non-null   float64
#  9   Outras_vendas   1509 non-null   float64
#  10  Vendas_globais  1509 non-null   float64
# dtypes: float64(6), int64(1), object(4)
# memory usage: 141.5+ KB

# %%
dados.duplicated().any()
# Out:
# np.False_

# %%
Total_jogos = dados.Nome.value_counts()

# %%
Total_jogos
# Out:
# Nome
# Pro Evolution Soccer 2008                    4
# Pro Evolution Soccer 2010                    4
# PES 2009: Pro Evolution Soccer               4
# Tekken 6                                     3
# Harry Potter and the Sorcerer's Stone        3
#                                             ..
# Last Window: The Secret of Cape West         1
# Final Fantasy XI: Treasures of Aht Urhgan    1
# Senran Kagura: Estival Versus                1
# Killer is Dead                               1
# Mana Khemia 2: Fall of Alchemy               1
# Name: count, Length: 1380, dtype: int64

# %%
Total_consoles = dados.Plataforma.value_counts()

# %%
Total_consoles
# Out:
# Plataforma
# PS3     254
# PS      233
# PS2     189
# DS      123
# Wii      89
# 3DS      81
# PS4      68
# PSP      66
# X360     59
# N64      50
# GBA      45
# NES      45
# GB       44
# GC       44
# PSV      36
# WiiU     32
# SNES     31
# XB        7
# GEN       5
# DC        4
# SAT       3
# SCD       1
# Name: count, dtype: int64

# %%
Total_genero = dados.Genero.value_counts()

# %%
Total_genero
# Out:
# Genero
# Role-Playing    314
# Action          308
# Sports          143
# Platform        137
# Fighting        125
# Shooter         122
# Racing           78
# Misc             76
# Simulation       76
# Puzzle           54
# Strategy         39
# Adventure        37
# Name: count, dtype: int64

# %%
Total_editoras = dados.Editora.value_counts()

# %%
Total_editoras
# Out:
# Editora
# Nintendo                        394
# Sony Computer Entertainment     148
# Namco Bandai Games              107
# Capcom                          107
# Konami Digital Entertainment    106
#                                ...
# Ignition Entertainment            1
# Indie Games                       1
# Axela                             1
# ArtDink                           1
# Xing Entertainment                1
# Name: count, Length: 86, dtype: int64

# %%
plt.figure(figsize=(10, 4))
sns.lineplot(dados , x = "Ano" , y = "Na_vendas" , color = 'b' , marker='o')
plt.title('Vendas nacionais por ano')
plt.xlabel('Ano')
plt.ylabel('Vendas nacionais')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10, 4))
sns.lineplot(dados , x = "Ano" , y = 'Vendas_globais' , color = 'y' ,  marker='o')
plt.title('Vendas globais por ano')
plt.xlabel('Ano')
plt.ylabel('Vendas globais')
plt.grid(True)
plt.show()

# %%
top_3 = dados.head(3)
top_3
# Out:
#    Classificacao               Nome Plataforma     Ano    Genero   Editora  \
# 0              1         Wii Sports        Wii  2006.0    Sports  Nintendo
# 1              2  Super Mario Bros.        NES  1985.0  Platform  Nintendo
# 2              3     Mario Kart Wii        Wii  2008.0    Racing  Nintendo
#
#    Na_vendas  EU_Sales  Jp_vendas  Outras_vendas  Vendas_globais
# 0      41.49     29.02       3.77           8.46           82.74
# 1      29.08      3.58       6.81           0.77           40.24
# 2      15.85     12.88       3.79           3.31           35.82

# %%
plt.figure(figsize=(6, 4))
sns.barplot(top_3, x = "Nome", y = 'Vendas_globais', hue='Classificacao')
plt.title('Top 3 de jogos - Vendas globais')
plt.xlabel('Nome do jogo')
plt.ylabel('Vendas globais')
plt.show()

# %%
# Selecionar apenas as colunas numéricas
colunas_numericas = dados.select_dtypes(include=['float64', 'int64']).columns
dados_numericos = dados[colunas_numericas]

# Calcular a correlação entre as variáveis numéricas
correlation_matriz = dados_numericos.corr()

# Criar uma matriz de anotações com os valores formatados
annotations = np.array([[f"{val:.2f}" for val in row] for row in correlation_matriz.to_numpy()])

# Plotar o heatmap da matriz de correlação
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matriz, annot=annotations, cmap='coolwarm', fmt='', linewidths=0.5)
plt.title('Heatmap da Matriz de Correlação')
plt.show()

# %%
dados.isna()
# Out:
#       Classificacao   Nome  Plataforma    Ano  Genero  Editora  Na_vendas  \
# 0             False  False       False  False   False    False      False
# 1             False  False       False  False   False    False      False
# 2             False  False       False  False   False    False      False
# 3             False  False       False  False   False    False      False
# 4             False  False       False  False   False    False      False
# ...             ...    ...         ...    ...     ...      ...        ...
# 7615          False  False       False   True   False    False      False
# 7665          False  False       False  False   False    False      False
# 7721          False  False       False  False   False    False      False
# 7728          False  False       False  False   False    False      False
# 7731          False  False       False  False   False    False      False
#
#       EU_Sales  Jp_vendas  Outras_vendas  Vendas_globais
# ...

# %%
dados.isna().sum()
# Out:
# Classificacao     0
# Nome              0
# Plataforma        0
# Ano               8
# Genero            0
# Editora           0
# Na_vendas         0
# EU_Sales          0
# Jp_vendas         0
# Outras_vendas     0
# Vendas_globais    0
# dtype: int64

# %%
# Análise de vendas por plataforma (console)
vendas_console = dados.groupby('Plataforma')['Vendas_globais'].sum().sort_values(ascending=False)
vendas_console.head()
# Out:
# Plataforma
# PS3    527.52
# Wii    440.71
# PS2    396.42
# DS     384.85
# PS     306.45
# Name: Vendas_globais, dtype: float64

# %%
plt.figure(figsize=(10,6))
vendas_console.plot(kind='bar', color='skyblue')
plt.title('Vendas globais por console')
plt.xlabel('Plataforma')
plt.ylabel('Vendas')
plt.xticks(rotation=45)
plt.show()

# %%
# Análise dos gêneros dos jogos

vendas_genero = dados.groupby('Genero')['Vendas_globais'].sum().sort_values(ascending=False)
vendas_genero.head()
# Out:
# Genero
# Action          686.58
# Role-Playing    583.83
# Platform        532.24
# Shooter         461.98
# Sports          403.13
# Name: Vendas_globais, dtype: float64

# %%
plt.figure(figsize=(10,6))
vendas_genero.plot(kind='bar', color='purple')
plt.title('Vendas globais por gênero de jogos')
plt.xlabel('Gênero')
plt.ylabel('Vendas')
plt.xticks(rotation=50)
plt.show()

# %%
dados['Ano'] = dados['Ano'].fillna(0)
dados.head()
# Out:
#    Classificacao                      Nome Plataforma     Ano        Genero  \
# 0              1                Wii Sports        Wii  2006.0        Sports
# 1              2         Super Mario Bros.        NES  1985.0      Platform
# 2              3            Mario Kart Wii        Wii  2008.0        Racing
# 3              4         Wii Sports Resort        Wii  2009.0        Sports
# 4              5  Pokemon Red/Pokemon Blue         GB  1996.0  Role-Playing
#
#     Editora  Na_vendas  EU_Sales  Jp_vendas  Outras_vendas  Vendas_globais
# 0  Nintendo      41.49     29.02       3.77           8.46           82.74
# 1  Nintendo      29.08      3.58       6.81           0.77           40.24
# 2  Nintendo      15.85     12.88       3.79           3.31           35.82
# 3  Nintendo      15.75     11.01       3.28           2.96           33.00
# 4  Nintendo      11.27      8.89      10.22           1.00           31.37

# %%
dados['Ano'].dtype
# Out:
# dtype('float64')

# %%
dados['Ano'] = dados['Ano'].astype('int64')

# %%
dados.head()
# Out:
#    Classificacao                      Nome Plataforma   Ano        Genero  \
# 0              1                Wii Sports        Wii  2006        Sports
# 1              2         Super Mario Bros.        NES  1985      Platform
# 2              3            Mario Kart Wii        Wii  2008        Racing
# 3              4         Wii Sports Resort        Wii  2009        Sports
# 4              5  Pokemon Red/Pokemon Blue         GB  1996  Role-Playing
#
#     Editora  Na_vendas  EU_Sales  Jp_vendas  Outras_vendas  Vendas_globais
# 0  Nintendo      41.49     29.02       3.77           8.46           82.74
# 1  Nintendo      29.08      3.58       6.81           0.77           40.24
# 2  Nintendo      15.85     12.88       3.79           3.31           35.82
# 3  Nintendo      15.75     11.01       3.28           2.96           33.00
# 4  Nintendo      11.27      8.89      10.22           1.00           31.37
